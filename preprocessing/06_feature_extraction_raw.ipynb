# %%
import sys
import os

sys.path.append(os.path.abspath('../feature_engineering'))

from feature_extraction import process_windowed_csv, process_ibi_windows

# %%
BASE ='
print(os.listdir(BASE))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 BASE = 'preprocessed_data/windows_raw'
# ----> 2 print(os.listdir(BASE))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'preprocessed_data/windows_raw'
