# %%
import pickle

with open("S3.pkl", "rb") as f:
    data = pickle.load(f)

print("Type:", type(data))

if isinstance(data, dict):
    print("\nKeys:")
    for key in data.keys():
        print(key)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pickle
#       2
# ----> 3 with open("S3.pkl", "rb") as f:
#       4     data = pickle.load(f)
#       5
#       6 print("Type:", type(data))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'S3.pkl'

# %%
import pickle
import numpy as np
import pandas as pd

file_path = "../data/raw/WESAD/S2/S2_E4_Data/EDA.csv"
with open(file_path, "rb") as f:
    data = pickle.load(f, encoding="latin1")

print(data.keys())
print(np.unique(data['label']))
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[11], line 7
#       3 import pandas as pd
#       4
#       5 file_path = "../data/raw/WESAD/S2/S2_E4_Data/EDA.csv"
#       6 with open(file_path, "rb") as f:
# ----> 7     data = pickle.load(f, encoding="latin1")
#       8
#       9 print(data.keys())
#      10 print(np.unique(data['label']))
#
# UnpicklingError: could not find MARK

# %%
import os

for root, dirs, files in os.walk("."):
    for file in files:
        if file == "EDA.csv":
            print(os.path.join(root, file))

# %%
import os

path = "data/raw/WESAD/S2/S2_E4_Data/EDA.csv"
print(os.path.exists(path))
# Out:
# False

# %%
import os

for root, dirs, files in os.walk("."):
    if "EDA.csv" in files:
        print(os.path.join(root, "EDA.csv"))

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\abhishek\Desktop\Stress Detection Project Somya\notebooks

# %%
# upsample the EDA with labels
import pickle
import numpy as np
import matplotlib.pyplot as plt

# Load data
with open("../data/raw/WESAD/S2/S2.pkl", "rb") as f:
    data = pickle.load(f, encoding="latin1")

eda = data['signal']['wrist']['EDA'].flatten()
labels = data['label']

# Upsample EDA to match label length
x_old = np.linspace(0, 1, len(eda))
x_new = np.linspace(0, 1, len(labels))

eda_up = np.interp(x_new, x_old, eda)

# Plot full signal
plt.figure(figsize=(20,6))
plt.plot(eda_up, linewidth=0.5)

# Label boundaries
changes = np.where(np.diff(labels) != 0)[0]

start = 0

for change in changes:
    middle = (start + change) // 2

    plt.text(
        middle,
        np.max(eda_up) * 0.95,
        str(int(labels[start])),   # shows 0,1,2,3...
        ha='center'
    )

    plt.axvline(change, color='red', linestyle='--', alpha=0.5)

    start = change + 1

# Last section
middle = (start + len(labels)) // 2

plt.text(
    middle,
    np.max(eda_up) * 0.95,
    str(int(labels[start])),
    ha='center'
)

plt.title("Upsampled EDA with Labels")
plt.xlabel("Samples")
plt.ylabel("EDA")
plt.grid(True)

plt.show()

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# Load data
with open("../data/raw/WESAD/S2/S2.pkl", "rb") as f:
    data = pickle.load(f, encoding="latin1")

labels = data['label']

def plot_signal(signal, signal_name):
    
    signal = np.array(signal).flatten()

    # Upsample signal to label length
    x_old = np.linspace(0, 1, len(signal))
    x_new = np.linspace(0, 1, len(labels))

    signal_up = np.interp(x_new, x_old, signal)

    plt.figure(figsize=(20,6))
    plt.plot(signal_up, linewidth=0.5)

    changes = np.where(np.diff(labels) != 0)[0]

    start = 0

    for change in changes:
        middle = (start + change) // 2

        plt.text(
            middle,
            np.max(signal_up) * 0.95,
            str(int(labels[start])),
            ha='center'
        )

        plt.axvline(change,
                    color='red',
                    linestyle='--',
                    alpha=0.5)

        start = change + 1

    middle = (start + len(labels)) // 2

    plt.text(
        middle,
        np.max(signal_up) * 0.95,
        str(int(labels[start])),
        ha='center'
    )

    plt.title(signal_name)
    plt.xlabel("Samples")
    plt.ylabel(signal_name)
    plt.grid(True)

    plt.show()
    plot_signal(
    data['signal']['wrist']['EDA'],
    "Wrist EDA"
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 6
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4
#       5 # Load data
# ----> 6 with open("data/raw/WESAD/S2/S2.pkl", "rb") as f:
#       7     data = pickle.load(f, encoding="latin1")
#       8
#       9 labels = data['label']
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/raw/WESAD/S2/S2.pkl'
